# %% [markdown]
# Setting up Darkflow and training YOLO

# %%
import tensorflow as tf
print(tf.__version__)
# !ls -lAh
# Out:
# 1.6.0
# total 32K
# drwx------ 4 root root 4.0K Apr  2 06:52 .cache
# drwxr-xr-x 3 root root 4.0K Apr  2 06:52 .config
# drwxr-xr-x 1 root root 4.0K Mar 13 21:48 datalab
# drwxr-xr-x 4 root root 4.0K Apr  2 06:42 .forever
# drwxr-xr-x 5 root root 4.0K Apr  2 06:52 .ipython
# drwxr-xr-x 2 root root 4.0K Apr  2 07:13 .keras
# drwx------ 3 root root 4.0K Apr  2 06:42 .local
# -rw------- 1 root root 1.0K Apr  2 06:42 .rnd

# %%
# !pip install opencv-contrib-python
# Out:
# ...
#     100% |████████████████████████████████| 30.5MB 45kB/s
# ...

# %%
# !apt update && apt install -y libsm6 libxext6
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu artful InRelease
# Get:2 http://archive.ubuntu.com/ubuntu artful-updates InRelease [81.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu artful-backports InRelease [72.2 kB]
# Get:4 http://security.ubuntu.com/ubuntu artful-security InRelease [78.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu artful-updates/universe Sources [36.1 kB]
# Get:6 http://archive.ubuntu.com/ubuntu artful-updates/universe amd64 Packages [126 kB]
# Get:7 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 Packages [296 kB]
# Get:8 http://archive.ubuntu.com/ubuntu artful-updates/multiverse amd64 Packages [4,381 B]
# Get:9 http://archive.ubuntu.com/ubuntu artful-backports/universe amd64 Packages [4,130 B]
# Get:10 http://security.ubuntu.com/ubuntu artful-security/universe Sources [15.7 kB]
# Get:11 http://security.ubuntu.com/ubuntu artful-security/main amd64 Packages [182 kB]
# Get:12 http://security.ubuntu.com/ubuntu artful-security/universe amd64 Packages [68.9 kB]
# ...

# %%
# !pip install Cython
# Out:
# ...
#     100% |████████████████████████████████| 3.4MB 372kB/s
# ...

# %%
# !git clone https://github.com/himanshurawlani/tiny-yolo-voc.git
# Out:
# Cloning into 'tiny-yolo-voc'...
# remote: Counting objects: 14782, done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 14782 (delta 43), reused 38 (delta 19), pack-reused 14714
# Receiving objects: 100% (14782/14782), 900.55 MiB | 46.04 MiB/s, done.
# Resolving deltas: 100% (6540/6540), done.
# Checking out files: 100% (9745/9745), done.

# %%
# !ls -l tiny-yolo-voc/
# Out:
# total 908
# drwxr-xr-x 2 root root   4096 Mar 31 12:55 bin
# drwxr-xr-x 4 root root   4096 Mar 31 12:55 built_graph
# drwxr-xr-x 8 root root   4096 Mar 31 12:55 darkflow
# -rw-r--r-- 1 root root   1472 Mar 31 12:55 extract_annotation_and_image_files.py
# -rw-r--r-- 1 root root 741401 Mar 31 12:55 imagenet_synset_to_human_label_map.txt
# -rw-r--r-- 1 root root   2153 Mar 31 12:55 process_training_data.py
# -rw-r--r-- 1 root root     78 Mar 31 12:55 README.md
# -rw-r--r-- 1 root root    675 Mar 31 12:55 rename_xml_names.py
# -rw-r--r-- 1 root root 153500 Mar 31 12:55 yolo_training_darkflow.ipynb

# %%
# !pip install tiny-yolo-voc/darkflow/. --upgrade
# Out:
# Processing ./tiny-yolo-voc/darkflow
# ...
# done
# ...

# %%
# !flow --h
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
#
# Example usage: flow --imgdir sample_img/ --model cfg/yolo.cfg --load bin/yolo.weights
#
# Arguments:
#   --help, --h, -h  show this super helpful message and exit
#   --imgdir         path to testing directory with images
#   --binary         path to .weights directory
#   --config         path to .cfg directory
#   --dataset        path to dataset directory
#   --labels         path to labels file
#   --backup         path to backup folder
#   --summary        path to TensorBoard summaries directory
#   --annotation     path to annotation directory
#   --threshold      detection threshold
#   --model          configuration of choice
#   --trainer        training algorithm
# ...

# %%
# !apt-get install tree
# !tree -d tiny-yolo-voc/darkflow/train/
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 11 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu artful/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 0s (457 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 16712 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# tiny-yolo-voc/darkflow/train/
# ├── Annotation
# └── Images
#
# 2 directories

# %%
# !cd tiny-yolo-voc/darkflow/ && cat labels.txt
# !cd tiny-yolo-voc/darkflow/train/Annotation/ && cat n07753592_10127.xml
# Out:
# apple
# banana
# broccoli
# cabbage
# capsicum
# cauliflower
# corn
# cucumber
# jackfruit
# pineapple
# pomogranate
# spinach
# strawberry
# <annotation>
# 	<folder>n07753592</folder>
# 	<filename>n07753592_10127.jpg</filename>
# 	<source>
# 		<database>ImageNet database</database>
# 	</source>
# 	<size>
# 		<width>320</width>
# 		<height>500</height>
# 		<depth>3</depth>
# 	</size>
# 	<segmented>0</segmented>
# 	<object>
# 		<name>banana</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>22</xmin>
# 			<ymin>50</ymin>
# 			<xmax>306</xmax>
# 			<ymax>498</ymax>
# 		</bndbox>
# 	</object>
# </annotation>

# %%
# !cd tiny-yolo-voc/ && git pull
# !ls -l tiny-yolo-voc/darkflow/cfg/
# !ls -l tiny-yolo-voc/darkflow/bin/
# Out:
# Already up-to-date.
# total 52
# -rw-r--r-- 1 root root  625 Mar 31 12:55 coco.names
# -rw-r--r-- 1 root root 2109 Mar 31 12:55 extraction.cfg
# -rw-r--r-- 1 root root 1689 Mar 31 12:55 extraction.conv.cfg
# -rw-r--r-- 1 root root 1405 Mar 31 12:55 tiny-yolo-4c.cfg
# -rw-r--r-- 1 root root 1426 Mar 31 12:55 tiny-yolo-coco-4c.cfg
# -rw-r--r-- 1 root root 1440 Mar 31 12:55 tiny-yolo-coco.cfg
# -rw-r--r-- 1 root root 1438 Mar 31 12:55 tiny-yolo-old.cfg
# -rw-r--r-- 1 root root 1407 Mar 31 12:55 tiny-yolo-voc-3c.cfg
# -rw-r--r-- 1 root root 1408 Mar 31 12:55 tiny-yolo-voc.cfg
# drwxr-xr-x 2 root root 4096 Mar 31 12:55 v1
# drwxr-xr-x 2 root root 4096 Mar 31 12:55 v1.1
# -rw-r--r-- 1 root root 2726 Mar 31 12:55 yolo.cfg
# -rw-r--r-- 1 root root 2554 Mar 31 12:55 yolo-voc.cfg
# total 105880
# -rw-r--r-- 1 root root 44948600 Mar 31 12:55 tiny-yolo-coco.weights
# -rw-r--r-- 1 root root 63471556 Mar 31 12:55 tiny-yolo-voc.weights

# %%
# !cd tiny-yolo-voc/darkflow/ && flow --model cfg/tiny-yolo-coco-4c.cfg --load bin/tiny-yolo-coco.weights --train --annotation "train/Annotation/" --dataset "train/Images/" --gpu 1.0 --batch 32 --trainer adam
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
#
# Parsing ./cfg/tiny-yolo-coco.cfg
# Parsing cfg/tiny-yolo-coco-4c.cfg
# Loading bin/tiny-yolo-coco.weights ...
# Successfully identified 44948600 bytes
# Finished in 0.007599830627441406s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
# ...

# %%
# !cd tiny-yolo-voc/darkflow/ && flow --model cfg/tiny-yolo-coco-4c.cfg --load -1 --train --annotation "train/Annotation/" --dataset "train/Images/" --gpu 1.0 --batch 32 --trainer adam
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
#
# Parsing cfg/tiny-yolo-coco-4c.cfg
# Loading None ...
# Finished in 9.322166442871094e-05s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 32)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 64)
# ...

# %%
# !cd tiny-yolo-voc/darkflow/ && flow --model cfg/tiny-yolo-coco-4c.cfg --load -1 --gpu 1.0
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
#
# Parsing cfg/tiny-yolo-voc-3c.cfg
# Loading None ...
# Finished in 6.890296936035156e-05s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 32)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 64)
# ...

# %%
# !ls -l tiny-yolo-voc/darkflow/sample_img/out/
# Out:
# total 484
# -rw-r--r-- 1 root root  17691 Feb 24 21:25 n07714571_81.JPEG
# -rw-r--r-- 1 root root 116153 Feb 24 21:25 n07715103_143.JPEG
# -rw-r--r-- 1 root root 116319 Feb 24 21:25 n07718472_418.JPEG
# -rw-r--r-- 1 root root  93172 Feb 24 21:25 n07753592_9454.jpg
# -rw-r--r-- 1 root root  87682 Feb 24 21:25 n07753592_9936.jpg
# -rw-r--r-- 1 root root  52913 Feb 24 21:25 n07840804_910.JPEG

# %%
# !cd tiny-yolo-voc/darkflow/ && flow --model cfg/tiny-yolo-coco-4c.cfg --load -1 --savepb --gpu 1.0
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
#
# Parsing cfg/tiny-yolo-coco-4c.cfg
# Loading None ...
# Finished in 6.747245788574219e-05s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 32)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 64)
# ...

# %%
# !ls -l tiny-yolo-voc/darkflow/built_graph/
# Out:
# total 43240
# -rw-r--r-- 1 root root     1453 Mar 31 21:52 tiny-yolo-coco-4c.meta
# -rw-r--r-- 1 root root 44271002 Mar 31 21:52 tiny-yolo-coco-4c.pb

# %%
# !cd tiny-yolo-voc/darkflow/ && flow --pbLoad built_graph/tiny-yolo-voc-3c.pb --metaLoad built_graph/tiny-yolo-voc-3c.meta --gpu 1.0
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
#
#
# Loading from .pb and .meta
# Running entirely on CPU
# 2018-02-22 19:26:39.176160: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:898] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-02-22 19:26:39.176784: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1208] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.11GiB
# 2018-02-22 19:26:39.176844: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1308] Adding visible gpu devices: 0
# Forwarding 3 inputs ...
# ...

# %%
from google.colab import files

files.download('tiny-yolo-voc/darkflow/built_graph/tiny-yolo-coco-4c.meta')
files.download('tiny-yolo-voc/darkflow/built_graph/tiny-yolo-coco-4c.pb')

# %%
# !stat -f tiny-yolo-voc/darkflow/built_graph/tiny-yolo-coco-4c.pb
# Out:
#   File: "tiny-yolo-voc/darkflow/built_graph/tiny-yolo-coco-4c.pb"
#     ID: ac3bc43598bba724 Namelen: 255     Type: overlayfs
# Block size: 4096       Fundamental block size: 4096
# Blocks: Total: 95683787   Free: 92544640   Available: 92540544
# Inodes: Total: 24210720   Free: 23928212

# %%
from google.colab import files

with open('example.txt', 'w') as f:
  f.write('some content')

files.download('example.txt')
